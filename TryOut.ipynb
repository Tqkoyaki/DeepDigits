# %% [markdown]
# ## Try the Models
#
# Create an image on https://www.pixilart.com/draw using the canvas.pixil template. Then, download the image as a .png file. Upload the image to images/pixel/[your image name].png. Then, run the following code to test the models.

# %%
import cv2
img = cv2.imread('images/pixel/pixil-frame-0.png')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (28, 28)

# %%
import matplotlib.pyplot as plt
plt.imshow(255 - gray)
